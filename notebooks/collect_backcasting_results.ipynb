# %%
import os, sys
os.chdir(os.path.abspath('..'))

# %%
import json
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
# %load_ext autoreload
# %autoreload 2

from src.vae_models import CVAE
import src.utils as utils
import src.preprocess_lib as preprocess_lib
import src.testing_lib as testing_lib

# %%
config_dir = 'runs/sweep_runs'
config_file = 'config.json'

# %%
device = "cuda:1"
NUM_REC_SAMPLES = 100
NUM_IMP_SAMPLES = {"prior": 20, "likelihood": 5}
IMPUTATION_STYLE = "mean" ## "samples" or "mean"

# %%
folders = os.listdir(config_dir)

# %%
for i, folder in enumerate(folders):
    if os.path.exists(os.path.join(config_dir, folder, "test_results.json")):
        print(f"Test results already exist for {folder}. Skipping...")
        continue

    test_results = {}
    # Load config file
    print(f"Loading config file for {folder}...")
    with open(os.path.join(config_dir, folder, config_file), 'r') as f: config = json.load(f)
    
    trainset, valset, conditioner, user_ids, condition_set, X_test, num_missing_days, nonzero_mean, nonzero_std = preprocess_lib.prepare_data(config["data"])
    num_missing_days = [x.shape[0] for x in X_test["list"]]
    num_users = len(num_missing_days)
    
    # Load model
    model = CVAE(input_dim=valset.inputs.shape[1], conditioner=conditioner, **config["model"])
    model.load(os.path.join(config_dir, folder))
    
    log_space = config["data"]["scaling"]["log_space"]
    zero_id = config["data"]["scaling"]["zero_id"]
    shift = config["data"]["scaling"]["shift"]
    
    print(f"Preparing test data for {folder}...")
    x_test = utils.zero_preserved_log_normalize(X_test["flat"]*1.0, nonzero_mean, nonzero_std, log_output=log_space, zero_id=zero_id, shift=shift)
    x_test = torch.tensor(x_test).float()
    conditions_test =  torch.tensor(conditioner.transform(condition_set["test"].copy())).float()
    
    print("Reconstructing...")
    x_rec, z_rec = testing_lib.mass_reconstruction(model, x_test, conditions_test, num_mc_samples=NUM_REC_SAMPLES, device=device)

    print("Calculating probabilistic metrics...")
    test_results["prob_metrics"] = testing_lib.get_probabilistic_metrics(model, x_test, x_rec, z_rec, aggregate=True, device=device)

    print("Imputing...")
    x_imp = testing_lib.mass_imputation(model, conditions_test, num_mc_samples_prior=NUM_IMP_SAMPLES["prior"], num_mc_samples_likelihood=NUM_IMP_SAMPLES["likelihood"], device=device)

    x_imp_denormalized = testing_lib.mass_denormalization(model=model, x_imp=x_imp, nonzero_mean=nonzero_mean, nonzero_std=nonzero_std, zero_id=zero_id, shift=shift, log_space=log_space, deviation=2, device=device)

    print("Calculating sample metrics...")
    test_results["sample_metrics"] = {}
    for imputation_style in ["samples", "mean"]:
        test_results["sample_metrics"][imputation_style] = {}
        test_results["sample_metrics"][imputation_style] = testing_lib.get_sample_metrics(x_test, x_imp_denormalized, imputation_style=imputation_style, aggregate=True)

    print("Saving results...")
    with open(os.path.join(config_dir, folder, "test_results.json"), 'w') as f:
        json.dump(test_results, f, indent=4)

    print(f"Finished testing {folder} ({i+1}/{len(folders)})")
# Out:
# Test results already exist for sweep_Jul31_12-40-23. Skipping...
# Test results already exist for sweep_Aug01_16-50-05. Skipping...
# Test results already exist for sweep_Jul31_15-58-49. Skipping...
# Test results already exist for sweep_Aug02_04-15-57. Skipping...
# Test results already exist for sweep_Aug03_12-16-18. Skipping...
# Test results already exist for sweep_Aug03_13-52-55. Skipping...
# Test results already exist for sweep_Aug04_06-21-40. Skipping...
# Test results already exist for sweep_Aug01_21-54-44. Skipping...
# Test results already exist for sweep_Aug04_15-20-31. Skipping...
# Test results already exist for sweep_Jul31_06-57-15. Skipping...
# Test results already exist for sweep_Aug03_23-38-10. Skipping...
# Test results already exist for sweep_Aug04_18-52-54. Skipping...
# Test results already exist for sweep_Aug04_11-47-08. Skipping...
# Test results already exist for sweep_Aug02_09-29-29. Skipping...
# Test results already exist for sweep_Aug01_09-25-45. Skipping...
# Test results already exist for sweep_Jul31_02-47-07. Skipping...
# Test results already exist for sweep_Aug02_06-17-12. Skipping...
# Test results already exist for sweep_Aug01_14-55-57. Skipping...
# Test results already exist for sweep_Jul30_19-13-25. Skipping...
# Test results already exist for sweep_Jul31_17-21-36. Skipping...
# Test results already exist for sweep_Aug01_01-21-57. Skipping...
# Test results already exist for sweep_Aug02_18-21-03. Skipping...
# Test results already exist for sweep_Aug04_21-46-17. Skipping...
# Test results already exist for sweep_Aug05_08-40-18. Skipping...
# Test results already exist for sweep_Aug03_18-24-46. Skipping...
# Test results already exist for sweep_Jul31_01-21-17. Skipping...
# Test results already exist for sweep_Aug01_20-13-22. Skipping...
# Test results already exist for sweep_Aug03_22-08-36. Skipping...
# Test results already exist for sweep_Jul31_21-58-38. Skipping...
# Test results already exist for sweep_Aug03_16-57-11. Skipping...
# Test results already exist for sweep_Aug01_07-28-02. Skipping...
# Test results already exist for sweep_Aug04_04-55-43. Skipping...
# Test results already exist for sweep_Jul31_14-26-27. Skipping...
# Test results already exist for sweep_Aug02_16-17-12. Skipping...
# Test results already exist for sweep_Jul31_20-30-20. Skipping...
# Test results already exist for sweep_Aug04_03-25-42. Skipping...
# Test results already exist for sweep_Aug05_07-08-47. Skipping...
# Test results already exist for sweep_Aug02_02-04-23. Skipping...
# Test results already exist for sweep_Aug04_23-13-24. Skipping...
# Test results already exist for sweep_Aug03_15-33-52. Skipping...
# Test results already exist for sweep_Aug04_20-17-15. Skipping...
# Test results already exist for sweep_Aug01_05-24-00. Skipping...
# Test results already exist for sweep_Aug04_09-52-34. Skipping...
# Test results already exist for sweep_Aug05_03-35-40. Skipping...
# Test results already exist for sweep_Aug01_23-58-30. Skipping...
# Test results already exist for sweep_Aug04_01-34-49. Skipping...
# Test results already exist for sweep_Aug05_05-31-23. Skipping...
# Test results already exist for sweep_Aug02_13-53-49. Skipping...
# Test results already exist for sweep_Aug04_13-38-03. Skipping...
# Test results already exist for sweep_Aug02_11-32-37. Skipping...
# Test results already exist for sweep_Aug04_07-47-45. Skipping...
# Test results already exist for sweep_Aug05_01-20-35. Skipping...
# Test results already exist for sweep_Jul31_09-59-50. Skipping...
# Test results already exist for sweep_Aug01_18-27-49. Skipping...
# Loading config file for sweep_Jul31_23-53-33...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Jul31_23-53-33...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul31_23-53-33 (55/70)
# Loading config file for sweep_Jul31_05-24-05...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 28.59
# Number of Training Points: 2065749
# Number of Validation Points: 229527
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Jul31_05-24-05...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul31_05-24-05 (56/70)
# Loading config file for sweep_Aug04_16-59-57...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 28.59
# Number of Training Points: 2065749
# Number of Validation Points: 229527
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Aug04_16-59-57...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug04_16-59-57 (57/70)
# Loading config file for sweep_Jul30_17-42-29...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Jul30_17-42-29...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul30_17-42-29 (58/70)
# Loading config file for sweep_Jul30_15-53-50...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Jul30_15-53-50...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul30_15-53-50 (59/70)
# Loading config file for sweep_Jul31_03-59-26...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Jul31_03-59-26...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul31_03-59-26 (60/70)
# Loading config file for sweep_Jul31_08-15-58...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 28.59
# Number of Training Points: 2065749
# Number of Validation Points: 229527
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Jul31_08-15-58...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul31_08-15-58 (61/70)
# Loading config file for sweep_Jul31_11-18-40...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 10.06
# Number of Training Points: 2180883
# Number of Validation Points: 242320
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Jul31_11-18-40...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul31_11-18-40 (62/70)
# Loading config file for sweep_Aug03_20-12-28...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING SIGMA_LIM!
# Preparing test data for sweep_Aug03_20-12-28...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug03_20-12-28 (63/70)
# Loading config file for sweep_Jul30_21-11-23...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Jul30_21-11-23...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Jul30_21-11-23 (64/70)
# Loading config file for sweep_Aug02_07-55-27...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 10.06
# Number of Training Points: 2180883
# Number of Validation Points: 242320
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug02_07-55-27...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug02_07-55-27 (65/70)
# Loading config file for sweep_Aug01_13-22-48...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 28.59
# Number of Training Points: 2065749
# Number of Validation Points: 229527
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug01_13-22-48...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug01_13-22-48 (66/70)
# Loading config file for sweep_Aug01_03-30-44...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug01_03-30-44...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug01_03-30-44 (67/70)
# Loading config file for sweep_Aug01_11-25-28...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 53.03
# Number of Training Points: 1913026
# Number of Validation Points: 212558
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug01_11-25-28...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug01_11-25-28 (68/70)
# Loading config file for sweep_Aug02_20-39-38...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 10.06
# Number of Training Points: 2180883
# Number of Validation Points: 242320
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug02_20-39-38...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug02_20-39-38 (69/70)
# Loading config file for sweep_Aug02_22-43-20...
# Dataset: goi4_dp_full_Gipuzkoa
# Loaded 2522880 consumption profiles from 365 dates and 6912 users.
# Loaded metadata for 1 provinces
# Uniqe provinces are: ['Gipuzkoa']
# Removing 15 users with all-zero consumption profiles
# Removing 67 users with any-negative consumption profiles
# Number of (subsampled/filtered) users....6830
# Number of (subsampled) days...............365
# Number of (aggregated) features............24
# Mean of enrolments: 10.06
# Number of Training Points: 2180883
# Number of Validation Points: 242320
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# USING SIGMA_LIM!
# USING MARGINAL_STD_LIM!
# Preparing test data for sweep_Aug02_22-43-20...
# Reconstructing...
# Calculating probabilistic metrics...
# Imputing...
# Calculating sample metrics...
# Saving results...
# Finished testing sweep_Aug02_22-43-20 (70/70)
